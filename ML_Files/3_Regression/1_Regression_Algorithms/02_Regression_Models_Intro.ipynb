# %% [markdown]
# ### numpy:
#
# NumPy stands for numeric Python, a python package for the computation and processing of the multi-dimensional and single-dimensional array elements.
#
# ### pandas:
#
# Pandas provide high-performance data manipulation in Python.
#
# ### matplotlib:
#
# Matplotlib is a library used for data visualization. It is mainly used for basic plotting. Visualization using Matplotlib generally consists of bars, pies, lines, scatter plots, and so on.
#
# ### seaborn:
#
# Seaborn is a library used for making statistical graphics of the dataset. It provides a variety of visualization patterns. It uses fewer syntax and has easily interesting default themes. It is used to summarize data in visualizations and show the data’s distribution.

# %% [markdown]
# ### When we are applying regression models?
#
# When the target varible having continuous values

# %% [markdown]
# ### Types of Regression
#
# 1) Linear Models
#
# 2) Non Linear Models

# %%
Linear Model:

Linear Regression
  Simple Linear regression
  Multiple linear regression
  Polynomial Linear regression
  Ridge Regression
  Lasso Regression
  Elascity Regularization

# %%
NoN Linear Models:

# %% [markdown]
# ### Types of Algorithms in the Regression
#
# 1) Simple Linear Regression
#
# 2) Multiple Linear Regression
#
# 3) Polynomial Regression
#
# 4) Decision Tree Regressor
#
# 5) Random Forest Regressor
#
# 6) Support Vector Regressor
#
# 7) KNN Regressor
#
# 8) Ridge Regularizations
#
# 9) Lasso Regularization
#
# 10) Elascity Regularization

# %% [markdown]
# ### Evaluation Metrics or Model Performance Calculation
#
# 1) MAE  -> Mean Absolute Error -> Value must Near to zero
#
# 2) MSE  -> Mean Square Error -> Value must Near to zero
#
# 3) RMSE  -> Root Mean Square Error -> Value must Near to zero
#
# 4) R Square  -> Calculate the Accuracy -> Value must Near to one -> Convert value to percentage
#
# 5) Adjusted RSquare  -> Calculate the Accuracy (When more feature are there means) -> Value must Near to one -> Convert value to percentage

# %% [markdown]
# ### https://www.statisticshowto.com/probability-and-statistics/statistics-definitions/

# %% [markdown]
# ## Mean Squared Error Example
#
# ### MSE formula = (1/n) * Σ(actual – forecast)2
#
# Where:
#
# n = number of items,
#
# Σ = summation notation,
#
# Actual = original or observed y-value,
#
# Forecast = y-value from regression.

# %%
The formula for the absolute error (Δx) is:

(Δx) = xi – x,

Where:
xi is the measurement,
x is the true value.

# %%
Mean Absolute Error
The Mean Absolute Error(MAE) is the average of all absolute errors. The formula is:
mean absolute error

# %%
Where:

n = the number of errors,
Σ = summation symbol (which means “add them all up”),
|xi – x| = the absolute errors.
